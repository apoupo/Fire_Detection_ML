# %%
import serial

ser = serial.Serial('COM6', 115200, timeout=1)

# %%
img = []
found = 0
while(1):
    if ser.readline() == key:
#     if ser.readline().decode("utf-8")  == key1:
        for i in range(26):
            img.append(ser.readline())
    break

# %%
img
# Out:
# [b'\r\n',
#  b'30.9, 29.4, 28.2, 28.2, 28.1, 28.1, 27.9, 28.0, 27.8, 28.0, 27.9, 28.2, 28.2, 28.1, 28.2, 28.1, 28.3, 28.4, 28.4, 28.5, 28.6, 28.6, 28.5, 28.5, 28.7, 28.9, 28.4, 28.4, 28.8, 28.8, 28.7, 28.9, \r\n',
#  b'29.6, 28.7, 28.1, 28.7, 28.1, 28.2, 27.9, 28.0, 27.9, 28.0, 28.1, 28.3, 28.2, 28.4, 28.6, 28.6, 28.3, 28.5, 28.3, 28.8, 28.6, 28.9, 28.8, 28.9, 28.8, 28.8, 28.7, 29.0, 28.9, 28.9, 29.0, 29.1, \r\n',
#  b'28.7, 28.3, 28.1, 28.4, 28.2, 28.2, 28.0, 28.1, 28.3, 28.2, 28.3, 28.4, 28.5, 28.6, 28.8, 28.8, 29.1, 28.9, 28.7, 29.0, 29.0, 28.8, 29.1, 29.1, 29.2, 29.2, 29.3, 29.2, 29.2, 29.5, 29.4, 29.2, \r\n',
#  b'28.4, 28.2, 28.3, 28.2, 28.2, 28.1, 28.2, 28.2, 28.3, 28.5, 28.5, 28.8, 28.6, 28.9, 28.8, 29.0, 29.0, 29.0, 29.1, 29.2, 29.2, 29.4, 29.1, 29.4, 29.1, 29.3, 29.3, 29.6, 29.3, 29.5, 29.5, 29.5, \r\n',
# ...

# %%
key1 = 'b\'\\r\\n\''
print(type(key))
print(type(key1))
print(key1==key)
# Out:
# <class 'bytes'>
# <class 'str'>
# False

# %%
key = ser.readline()
print(key)

# %%
ser.close()

# %%
key
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2172/3064378186.py in <module>
# ----> 1 key
#
# NameError: name 'key' is not defined
